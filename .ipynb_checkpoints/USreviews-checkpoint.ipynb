# %%
import pandas as pd

# %%
#import CSV
wineUS_file = "Resources/winereview.csv"
wineUS_df = pd.read_csv(wineUS_file)
wineUS_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
wineUS_df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
reduced_wineUS_df = wineUS_df[["country", "description","points","price","province","region_1","title","variety","winery"]].copy()

reduced_wineUS_df.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#             province             region_1  \
# 0  Sicily & Sardinia                 Etna
# 1              Douro                  NaN
# 2             Oregon    Willamette Valley
# 3           Michigan  Lake Michigan Shore
# 4             Oregon    Willamette Valley
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...

# %%
wineUS_transformed_df = reduced_wineUS_df.copy()

wineUS_transformed_df = wineUS_transformed_df.rename(columns={"country":"Country",
                                                                "description":"Description",
                                                                "points":"Points",
                                                                "price":"Price",
                                                                "province":"State",
                                                                "region_1":"Region",
                                                                "title":"Name",
                                                                "variety":"Variety",
                                                                "winery":"Winery"
                                                               })

wineUS_transformed_df.head()
# Out:
#     Country                                        Description  Points  Price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#                State               Region  \
# 0  Sicily & Sardinia                 Etna
# 1              Douro                  NaN
# 2             Oregon    Willamette Valley
# 3           Michigan  Lake Michigan Shore
# 4             Oregon    Willamette Valley
#
#                                                 Name         Variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...

# %%
final_wineUS = ["US"]
final_wineUS
# Out:
# ['US']

# %%
USfilter = wineUS_transformed_df.Country.isin(final_wineUS)

# %%
wineUS_reviews_df = wineUS_transformed_df[USfilter]
wineUS_reviews_df
# Out:
#        Country                                        Description  Points  \
# 2           US  Tart and snappy, the flavors of lime flesh and...      87
# 3           US  Pineapple rind, lemon pith and orange blossom ...      87
# 4           US  Much like the regular bottling from 2012, this...      87
# 10          US  Soft, supple plum envelopes an oaky structure ...      87
# 12          US  Slightly reduced, this wine offers a chalky, t...      87
# ...        ...                                                ...     ...
# 129945      US  Hailing from one of the more popular vineyards...      90
# 129949      US  There's no bones about the use of oak in this ...      90
# 129950      US  This opens with herbaceous dollops of thyme an...      90
# 129952      US  This Zinfandel from the eastern section of Nap...      90
# 129967      US  Citation is given as much as a decade of bottl...      90
#
#         Price       State               Region  \
# ...

# %%
# Imports
import pandas as pd
import pymongo
from pymongo import MongoClient

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.wine_db
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'wine_db')

# %%
wine = db.wine

# %%
wineUS_reviews_df.to_dict('reviews')
# Out:
# [{'Country': 'US',
#   'Description': 'Tart and snappy, the flavors of lime flesh and rind dominate. Some green pineapple pokes through, with crisp acidity underscoring the flavors. The wine was all stainless-steel fermented.',
#   'Points': 87,
#   'Price': 14.0,
#   'State': 'Oregon',
#   'Region': 'Willamette Valley',
#   'Name': 'Rainstorm 2013 Pinot Gris (Willamette Valley)',
#   'Variety': 'Pinot Gris',
#   'Winery': 'Rainstorm'},
#  {'Country': 'US',
#   'Description': 'Pineapple rind, lemon pith and orange blossom start off the aromas. The palate is a bit more opulent, with notes of honey-drizzled guava and mango giving way to a slightly astringent, semidry finish.',
#   'Points': 87,
#   'Price': 13.0,
#   'State': 'Michigan',
#   'Region': 'Lake Michigan Shore',
#   'Name': 'St. Julian 2013 Reserve Late Harvest Riesling (Lake Michigan Shore)',
#   'Variety': 'Riesling',
#   'Winery': 'St. Julian'},
#  {'Country': 'US',
# ...

# %%
db.wine.insert_many(wineUS_reviews_df.to_dict('records'))
